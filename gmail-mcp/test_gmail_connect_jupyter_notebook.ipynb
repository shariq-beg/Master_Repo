# %%
import os
os.chdir(r"c:\VS Code\VS Code Projects\gmail-mcp")
from gmail_client import search_emails, read_email

results = search_emails("category:promotions", 5)
print("Search results:")
print(results)

if results:
    first_id = results[0]["id"]
    print("\nReading first email:\n")
    email_data = read_email(first_id)
    print(email_data)
else:
    print("No matching emails found.")
# Out:
# Search results:
# [{'id': '19d3363efc28211d', 'threadId': '19d3363efc28211d'}, {'id': '19d335063f405ebd', 'threadId': '19d335063f405ebd'}, {'id': '19d3307f38bba28e', 'threadId': '19d3307f38bba28e'}, {'id': '19d32fe8d42a672b', 'threadId': '19d32fe8d42a672b'}, {'id': '19d32f951090049a', 'threadId': '19d32f951090049a'}]
#
# Reading first email:
#
# {'id': '19d3363efc28211d', 'thread_id': '19d3363efc28211d', 'subject': 'Recent sales for Riverstone + more', 'from': '"realestate.com.au" <hello@email.realestate.com.au>', 'snippet': 'See the latest results in your area. \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c \u200c', 'label_ids': ['CATEGORY_PROMOTIONS', 'UNREAD', 'INBOX']}
